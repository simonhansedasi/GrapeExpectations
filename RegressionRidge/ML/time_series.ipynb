# %%
import pandas as pd

# %%
df = pd.read_pickle('../data/df.pkl')

# %%
features = [
    'plot_id',
    'curve_mean',
    'curve_min',
    'curve_max',
    'pro_curve_mean',
    'pro_curve_min',
    'pro_curve_max',
    'plan_curve_mean',
    'plan_curve_min',
    'plan_curve_max',
    'elev_min',
    'elev_max',
    'elev_mean',
    'elev_dev_min',
    'elev_dev_max',
    'elev_dev_mean',
    'total_relief',
    'area_m2',
    'area_ha',
    'aspect_min_cos',
    'aspect_min_sin',
    'aspect_max_cos',
    'aspect_max_sin',
    'aspect_mean_cos',
    'aspect_mean_sin',
    'slope_rad',
    'slope_grad',
    'slope_x',
    'slope_y',
    'local_relief',
    'total_relief_log',
    'sandtotal_r',
    'silttotal_r',
    'claytotal_r',
    'awc_r',
    'cec7_r',
    'om_r',
    'ph1to1h2o_r',
    'ec_r',
    'profile_depth',
    'max_depth',
    'frag3to10_r',
    'fraggt10_r',
    'dbovendry_r',
    'caco3_r'
]

# %%
plot_features = df[features][df['year'] == 2016]

# %%
df = pd.read_pickle('../data/ndvi/plots/ndvi_daily_interp.pkl')

plot_id = 3210
df = df[
    # (df['year'] == 2024) &
    (df['plot_id'] == plot_id)
].copy()

df = df.set_index('index')
df
# Out:
#             ndvi  plot_id  ndvi_smooth  ndvi_residual  ndvi_residual_pct  \
# index
# 2016-01-01   NaN   3210.0          NaN            NaN                NaN
# 2016-01-02   NaN   3210.0          NaN            NaN                NaN
# 2016-01-03   NaN   3210.0          NaN            NaN                NaN
# 2016-01-04   NaN   3210.0          NaN            NaN                NaN
# 2016-01-05   NaN   3210.0          NaN            NaN                NaN
# ...          ...      ...          ...            ...                ...
# 2024-12-27   NaN   3210.0          NaN            NaN                NaN
# 2024-12-28   NaN   3210.0          NaN            NaN                NaN
# 2024-12-29   NaN   3210.0          NaN            NaN                NaN
# 2024-12-30   NaN   3210.0          NaN            NaN                NaN
# 2024-12-31   NaN   3210.0          NaN            NaN                NaN
#
#             month  week  year  ndvi_smooth_interp
# index
# ...

# %%
plot_features[plot_features['plot_id'] == plot_id]
# Out:
#        plot_id  curve_mean  curve_min  curve_max  pro_curve_mean  \
# 28890     3210   -0.000241  -0.014176   0.014474        0.000248
#
#        pro_curve_min  pro_curve_max  plan_curve_mean  plan_curve_min  \
# 28890      -0.014643       0.022058        -0.000241       -0.014176
#
#        plan_curve_max  ...    cec7_r      om_r  ph1to1h2o_r      ec_r  \
# 28890        0.014474  ...  3.651316  0.325658          7.9  0.848684
#
#        profile_depth  max_depth  frag3to10_r  fraggt10_r  dbovendry_r  \
# 28890          152.0      152.0          0.0         0.0     1.662434
#
#         caco3_r
# 28890  1.697368
#
# [1 rows x 45 columns]

# %%
# df = df.merge(plot_features, how = 'inner', on = 'plot_id')

# %%
# df = df[df['plot_id'] == 487].copy()
# df = df.merge(pb
lot_features, how = 'inner', on = 'plot_id')

# %%
df
# Out:
#           index  ndvi  plot_id  ndvi_smooth  ndvi_residual  ndvi_residual_pct  \
# 0    2016-01-01   NaN    487.0          NaN            NaN                NaN
# 1    2016-01-02   NaN    487.0          NaN            NaN                NaN
# 2    2016-01-03   NaN    487.0          NaN            NaN                NaN
# 3    2016-01-04   NaN    487.0          NaN            NaN                NaN
# 4    2016-01-05   NaN    487.0          NaN            NaN                NaN
# ...         ...   ...      ...          ...            ...                ...
# 3283 2024-12-27   NaN    487.0          NaN            NaN                NaN
# 3284 2024-12-28   NaN    487.0          NaN            NaN                NaN
# 3285 2024-12-29   NaN    487.0          NaN            NaN                NaN
# 3286 2024-12-30   NaN    487.0          NaN            NaN                NaN
# 3287 2024-12-31   NaN    487.0          NaN            NaN                NaN
#
# ...

# %%
df_train = df[
    # (df['year'] != 2023) &
    (df['year'] != 2024)
].copy()

df_test = df[
    # (df['year'] == 2023) |
    (df['year'] == 2024)
].copy()

# %%
# df = df.set_index('index').sort_index()
# df_train = df_train.set_index('index').sort_index()
# df_test = df_test.set_index('index').sort_index()

# %%
from statsmodels.tsa.seasonal import STL

# Choose one plot
# pid = 42   # example
# plot_df = df[df['plot_id'] == pid].copy()
plot_df = df

series = plot_df['ndvi_smooth_interp']

# STL
stl = STL(series, period=365, robust=True)
res = stl.fit()

plot_df['trend'] = res.trend
plot_df['seasonal'] = res.seasonal
plot_df['resid'] = res.resid

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(4,1, figsize=(14,10), sharex=True)

axs[0].plot(series, label='NDVI')
axs[0].set_title('Original')

axs[1].plot(res.trend, color='orange')
axs[1].set_title('Trend')

axs[2].plot(res.seasonal, color='green')
axs[2].set_title('Seasonal')

axs[3].plot(res.resid, color='red')
axs[3].set_title('Residual')

plt.tight_layout()
plt.show()

# %%
plot_df
# Out:
#           index  ndvi  plot_id  ndvi_smooth  ndvi_residual  ndvi_residual_pct  \
# 0    2016-01-01   NaN    487.0          NaN            NaN                NaN
# 1    2016-01-02   NaN    487.0          NaN            NaN                NaN
# 2    2016-01-03   NaN    487.0          NaN            NaN                NaN
# 3    2016-01-04   NaN    487.0          NaN            NaN                NaN
# 4    2016-01-05   NaN    487.0          NaN            NaN                NaN
# ...         ...   ...      ...          ...            ...                ...
# 3283 2024-12-27   NaN    487.0          NaN            NaN                NaN
# 3284 2024-12-28   NaN    487.0          NaN            NaN                NaN
# 3285 2024-12-29   NaN    487.0          NaN            NaN                NaN
# 3286 2024-12-30   NaN    487.0          NaN            NaN                NaN
# 3287 2024-12-31   NaN    487.0          NaN            NaN                NaN
#
# ...
